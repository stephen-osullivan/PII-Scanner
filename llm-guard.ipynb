# %%
from llm_guard.vault import Vault
vault = Vault()

# %%
from llm_guard.input_scanners import Anonymize
from llm_guard.input_scanners.anonymize_helpers import DEBERTA_AI4PRIVACY_v2_CONF

scanner = Anonymize(vault, preamble="Insert before prompt", allowed_names=["John Doe"], hidden_names=["Test LLC"],
                    recognizer_conf=DEBERTA_AI4PRIVACY_v2_CONF, language="en", entity_types=["PERSON", "LOCATION", 'EMAIL_ADDRESS'])
# Out:
# 2024-07-02 17:34:11 [debug    ] Initialized NER model          device=device(type='cuda', index=0) model=Model(path='Isotonic/deberta-v3-base_finetuned_ai4privacy_v2', subfolder='', revision='9ea992753ab2686be4a8f64605ccc7be197ad794', onnx_path='Isotonic/deberta-v3-base_finetuned_ai4privacy_v2', onnx_revision='9ea992753ab2686be4a8f64605ccc7be197ad794', onnx_subfolder='onnx', onnx_filename='model.onnx', kwargs={}, pipeline_kwargs={'batch_size': 1, 'device': device(type='cuda', index=0), 'aggregation_strategy': 'simple'}, tokenizer_kwargs={'model_input_names': ['input_ids', 'attention_mask']})
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 from llm_guard.input_scanners import Anonymize
#       2 from llm_guard.input_scanners.anonymize_helpers import DEBERTA_AI4PRIVACY_v2_CONF
# ----> 4 scanner = Anonymize(vault, preamble="Insert before prompt", allowed_names=["John Doe"], hidden_names=["Test LLC"],
#       5                     recognizer_conf=DEBERTA_AI4PRIVACY_v2_CONF, language="en", entity_types=["PERSON", "LOCATION", 'EMAIL_ADDRESS'])
#
# File ~/projects/PII-Scanner/.venv/lib/python3.10/site-packages/llm_guard/input_scanners/anonymize.py:115, in Anonymize.__init__(self, vault, hidden_names, allowed_names, entity_types, preamble, regex_patterns, use_faker, recognizer_conf, threshold, use_onnx, language)
#     112 if not recognizer_conf:
#     113     recognizer_conf = DEBERTA_AI4PRIVACY_v2_CONF
# --> 115 transformers_recognizer = get_transformers_recognizer(
#     116     recognizer_conf=recognizer_conf,
#     117     use_onnx=use_onnx,
#     118     supported_language=language,
#     119 )
#     121 self._analyzer = get_analyzer(
#     122     recognizer=transformers_recognizer,
#     123     regex_groups=get_regex_patterns(regex_patterns),
#     124     custom_names=hidden_names,
#     125     supported_languages=list(set(["en", language])),
#     126 )
#
# File ~/projects/PII-Scanner/.venv/lib/python3.10/site-packages/llm_guard/input_scanners/anonymize_helpers/analyzer.py:131, in get_transformers_recognizer(recognizer_conf, use_onnx, supported_language)
#     125 supported_entities = recognizer_conf.get("PRESIDIO_SUPPORTED_ENTITIES")
#     126 transformers_recognizer = TransformersRecognizer(
#     127     model=model,
#     128     supported_entities=supported_entities,
#     129     supported_language=supported_language,
#     130 )
# --> 131 transformers_recognizer.load_transformer(
#     132     use_onnx=use_onnx,
#     133     **recognizer_conf,
#     134 )
#     135 return transformers_recognizer
#
# File ~/projects/PII-Scanner/.venv/lib/python3.10/site-packages/llm_guard/input_scanners/anonymize_helpers/transformers_recognizer.py:131, in TransformersRecognizer.load_transformer(self, use_onnx, **kwargs)
#     121     self.model = Model(
#     122         path="dslim/bert-base-NER",
#     123         onnx_path="dslim/bert-base-NER",
#     124         onnx_subfolder="onnx",
#     125     )
#     126     LOGGER.warning(
#     127         "'model' argument is None. Using default",
#     128         model=self.model,
#     129     )
# --> 131 self._load_pipeline(
#     132     use_onnx=use_onnx,
#     133 )
#
# File ~/projects/PII-Scanner/.venv/lib/python3.10/site-packages/llm_guard/input_scanners/anonymize_helpers/transformers_recognizer.py:145, in TransformersRecognizer._load_pipeline(self, use_onnx)
#     142 self.model.pipeline_kwargs["ignore_labels"] = self.ignore_labels
#     144 transformers = cast("transformers", lazy_load_dep("transformers"))
# --> 145 self.pipeline = transformers.pipeline(
#     146     "ner",
#     147     model=tf_model,
#     148     tokenizer=tf_tokenizer,
#     149     **self.model.pipeline_kwargs,
#     150 )
#     152 self.is_loaded = True
#
# File ~/projects/PII-Scanner/.venv/lib/python3.10/site-packages/transformers/pipelines/__init__.py:1108, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1105 if device is not None:
#    1106     kwargs["device"] = device
# -> 1108 return pipeline_class(model=model, framework=framework, task=task, **kwargs)
#
# File ~/projects/PII-Scanner/.venv/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:135, in TokenClassificationPipeline.__init__(self, args_parser, *args, **kwargs)
#     134 def __init__(self, args_parser=TokenClassificationArgumentHandler(), *args, **kwargs):
# --> 135     super().__init__(*args, **kwargs)
#     136     self.check_model_type(
#     137         TF_MODEL_FOR_TOKEN_CLASSIFICATION_MAPPING_NAMES
#     138         if self.framework == "tf"
#     139         else MODEL_FOR_TOKEN_CLASSIFICATION_MAPPING_NAMES
#     140     )
#     142     self._basic_tokenizer = BasicTokenizer(do_lower_case=False)
#
# File ~/projects/PII-Scanner/.venv/lib/python3.10/site-packages/transformers/pipelines/base.py:883, in Pipeline.__init__(self, model, tokenizer, feature_extractor, image_processor, modelcard, framework, task, args_parser, device, torch_dtype, binary_output, **kwargs)
#     876 # We shouldn't call `model.to()` for models loaded with accelerate as well as the case that model is already on device
#     877 if (
#     878     self.framework == "pt"
#     879     and self.model.device != self.device
#     880     and not (isinstance(self.device, int) and self.device < 0)
#     881     and hf_device_map is None
#     882 ):
# --> 883     self.model.to(self.device)
#     885 # Update config and generation_config with task specific parameters
#     886 task_specific_params = self.model.config.task_specific_params
#
# File ~/projects/PII-Scanner/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:2724, in PreTrainedModel.to(self, *args, **kwargs)
#    2719     if dtype_present_in_args:
#    2720         raise ValueError(
#    2721             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    2722             " `dtype` by passing the correct `torch_dtype` argument."
#    2723         )
# -> 2724 return super().to(*args, **kwargs)
#
# File ~/projects/PII-Scanner/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1145, in Module.to(self, *args, **kwargs)
#    1141         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                     non_blocking, memory_format=convert_to_format)
#    1143     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1145 return self._apply(convert)
#
# File ~/projects/PII-Scanner/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File ~/projects/PII-Scanner/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File ~/projects/PII-Scanner/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File ~/projects/PII-Scanner/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:820, in Module._apply(self, fn)
#     816 # Tensors stored in modules are graph leaves, and we don't want to
#     817 # track autograd history of `param_applied`, so we have to use
#     818 # `with torch.no_grad():`
#     819 with torch.no_grad():
# --> 820     param_applied = fn(param)
#     821 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     822 if should_use_set_data:
#
# File ~/projects/PII-Scanner/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1143, in Module.to.<locals>.convert(t)
#    1140 if convert_to_format is not None and t.dim() in (4, 5):
#    1141     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                 non_blocking, memory_format=convert_to_format)
# -> 1143 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# KeyboardInterrupt:

# %%
prompt = """
Kevin Mcarthur was a lonely man. 
He lived at 33 Drury Road, KT6 8SK. 
His File id is 9293010.
He likes swimming and fishing and recently had some trouble opening a bank account in Halifax. His email is kevmac@hotmail.com"""

sanitized_prompt, is_valid, risk_score = scanner.scan(prompt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       1 prompt = """
#       2 Kevin Mcarthur was a lonely man.
#       3 He lived at 33 Drury Road, KT6 8SK.
#       4 His File id is 9293010.
#       5 He likes swimming and fishing and recently had some trouble opening a bank account in Halifax. His email is kevmac@hotmail.com"""
# ----> 7 sanitized_prompt, is_valid, risk_score = scanner.scan(prompt)
#
# NameError: name 'scanner' is not defined

# %%
sanitized_prompt
# Out:
# 'Insert before prompt[REDACTED_PERSON_1][REDACTED_PERSON_2][REDACTED_PERSON_3] was a lonely man. He lived at [REDACTED_LOCATION_1], [REDACTED_LOCATION_2][REDACTED_LOCATION_3]. He likes swimming and fishing and recently had some trouble opening a bank account in [REDACTED_LOCATION_4]. His email is [REDACTED_EMAIL_ADDRESS_1]'

# %%
from llm_guard.input_scanners import Secrets

scanner = Secrets()
prompt = """

# syntax=docker/dockerfile:1

# NOTE: Building this image require's docker version >= 23.0.
#
# For reference:
# - https://docs.docker.com/build/dockerfile/frontend/#stable-channel

ARG BASE_IMAGE=ubuntu:22.04
ARG PYTHON_VERSION=3.11

FROM ${BASE_IMAGE} as dev-base
RUN apt-get update && DEBIAN_FRONTEND=noninteractive apt-get install -y --no-install-recommends \
        build-essential \
        ca-certificates \
        ccache \
        cmake \
        curl \
        git \
        libjpeg-dev \
        libpng-dev && \
    rm -rf /var/lib/apt/lists/*
RUN /usr/sbin/update-ccache-symlinks
RUN mkdir /opt/ccache && ccache --set-config=cache_dir=/opt/ccache
ENV PATH /opt/conda/bin:$PATH

FROM dev-base as conda
ARG PYTHON_VERSION=3.11
# Automatically set by buildx
ARG TARGETPLATFORM
# translating Docker's TARGETPLATFORM into miniconda arches
RUN case ${TARGETPLATFORM} in \
         "linux/arm64")  MINICONDA_ARCH=aarch64  ;; \
         *)              MINICONDA_ARCH=x86_64   ;; \
    esac && \
    curl -fsSL -v -o ~/miniconda.sh -O  "https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-${MINICONDA_ARCH}.sh"
COPY requirements.txt .
# Manually invoke bash on miniconda script per https://github.com/conda/conda/issues/10431
RUN chmod +x ~/miniconda.sh && \
    bash ~/miniconda.sh -b -p /opt/conda && \
    rm ~/miniconda.sh && \
    /opt/conda/bin/conda install -y python=${PYTHON_VERSION} cmake conda-build pyyaml numpy ipython && \
    /opt/conda/bin/python -mpip install -r requirements.txt && \
    /opt/conda/bin/conda clean -ya

FROM dev-base as submodule-update
WORKDIR /opt/pytorch
COPY . .
RUN git submodule update --init --recursive

FROM conda as build
ARG CMAKE_VARS
WORKDIR /opt/pytorch
COPY --from=conda /opt/conda /opt/conda
COPY --from=submodule-update /opt/pytorch /opt/pytorch
RUN make triton
RUN --mount=type=cache,target=/opt/ccache \
    export eval ${CMAKE_VARS} && \
    TORCH_CUDA_ARCH_LIST="7.0 7.2 7.5 8.0 8.6 8.7 8.9 9.0 9.0a" TORCH_NVCC_FLAGS="-Xfatbin -compress-all" \
    CMAKE_PREFIX_PATH="$(dirname $(which conda))/../" \
    python setup.py install

FROM conda as conda-installs
ARG PYTHON_VERSION=3.11
ARG CUDA_VERSION=12.1
ARG CUDA_CHANNEL=nvidia
ARG INSTALL_CHANNEL=pytorch-nightly
# Automatically set by buildx
RUN /opt/conda/bin/conda update -y -n base -c defaults conda
RUN /opt/conda/bin/conda install -c "${INSTALL_CHANNEL}" -y python=${PYTHON_VERSION}

ARG TARGETPLATFORM

# On arm64 we can only install wheel packages.
RUN case ${TARGETPLATFORM} in \
         "linux/arm64")  pip install --extra-index-url https://download.pytorch.org/whl/cpu/ torch torchvision torchaudio ;; \
         *)              /opt/conda/bin/conda install -c "${INSTALL_CHANNEL}" -c "${CUDA_CHANNEL}" -y "python=${PYTHON_VERSION}" pytorch torchvision torchaudio "pytorch-cuda=$(echo $CUDA_VERSION | cut -d'.' -f 1-2)"  ;; \
    esac && \
    /opt/conda/bin/conda clean -ya
RUN /opt/conda/bin/pip install torchelastic

FROM ${BASE_IMAGE} as official
ARG PYTORCH_VERSION
ARG TRITON_VERSION
ARG TARGETPLATFORM
ARG CUDA_VERSION
LABEL com.nvidia.volumes.needed="nvidia_driver"
RUN apt-get update && DEBIAN_FRONTEND=noninteractive apt-get install -y --no-install-recommends \
        ca-certificates \
        libjpeg-dev \
        libpng-dev \
        && rm -rf /var/lib/apt/lists/* \
        api_key = sk-w1ii3kalkdakla2
COPY --from=conda-installs /opt/conda /opt/conda
RUN if test -n "${TRITON_VERSION}" -a "${TARGETPLATFORM}" != "linux/arm64"; then \
        DEBIAN_FRONTEND=noninteractive apt install -y --no-install-recommends gcc; \
        rm -rf /var/lib/apt/lists/*; \
    fi
ENV PATH /opt/conda/bin:$PATH
ENV NVIDIA_VISIBLE_DEVICES all
ENV NVIDIA_DRIVER_CAPABILITIES compute,utility
ENV LD_LIBRARY_PATH /usr/local/nvidia/lib:/usr/local/nvidia/lib64
ENV PATH /usr/local/nvidia/bin:/usr/local/cuda/bin:$PATH
ENV PYTORCH_VERSION ${PYTORCH_VERSION}
ENV GCP_TOKEN ya29.c.b0Ae-h-sBAAAAAAAAAAAnp9CAdaXQivDNqDXdpTsSpDy3FrCDc6ZoUEZrwbV-vhZRrd_YeHJ3A7WuJUcqb7O3vCBBP2aPTVVvXZ
WORKDIR /workspace

FROM official as dev
# Should override the already installed version from the official-image stage
COPY --from=build /opt/conda /opt/conda

password = 123456789a1234
"""
sanitized_prompt, is_valid, risk_score = scanner.scan(prompt)
print(sanitized_prompt)
# Out:
# 2024-06-19 14:53:20 [warning  ] Detected secrets in prompt     secret_types=['Hex High Entropy String']
#
#
# # syntax=docker/dockerfile:1
#
# # NOTE: Building this image require's docker version >= 23.0.
# #
# # For reference:
# # - https://docs.docker.com/build/dockerfile/frontend/#stable-channel
#
# ARG BASE_IMAGE=ubuntu:22.04
# ARG PYTHON_VERSION=3.11
#
# FROM ${BASE_IMAGE} as dev-base
# RUN apt-get update && DEBIAN_FRONTEND=noninteractive apt-get install -y --no-install-recommends         build-essential         ca-certificates         ccache         cmake         curl         git         libjpeg-dev         libpng-dev &&     rm -rf /var/lib/apt/lists/*
# RUN /usr/sbin/update-ccache-symlinks
# RUN mkdir /opt/ccache && ccache --set-config=cache_dir=/opt/ccache
# ENV PATH /opt/conda/bin:$PATH
#
# FROM dev-base as conda
# ARG PYTHON_VERSION=3.11
# # Automatically set by buildx
# ARG TARGETPLATFORM
# # translating Docker's TARGETPLATFORM into miniconda arches
# RUN case ${TARGETPLATFORM} in          "linux/arm64")  MINICONDA_ARCH=aarch64  ;;          *)              MINICONDA_ARCH=x86_64   ;;     esac &&     curl -fsSL -v -o ~/miniconda.sh -O  "https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-${MINICONDA_ARCH}.sh"
# COPY requirements.txt .
# # Manually invoke bash on miniconda script per https://github.com/conda/conda/issues/10431
# RUN chmod +x ~/miniconda.sh &&     bash ~/miniconda.sh -b -p /opt/conda &&     rm ~/miniconda.sh &&     /opt/conda/bin/conda install -y python=${PYTHON_VERSION} cmake conda-build pyyaml numpy ipython &&     /opt/conda/bin/python -mpip install -r requirements.txt &&     /opt/conda/bin/conda clean -ya
#
# FROM dev-base as submodule-update
# WORKDIR /opt/pytorch
# COPY . .
# RUN git submodule update --init --recursive
#
# FROM conda as build
# ARG CMAKE_VARS
# WORKDIR /opt/pytorch
# COPY --from=conda /opt/conda /opt/conda
# COPY --from=submodule-update /opt/pytorch /opt/pytorch
# RUN make triton
# RUN --mount=type=cache,target=/opt/ccache     export eval ${CMAKE_VARS} &&     TORCH_CUDA_ARCH_LIST="7.0 7.2 7.5 8.0 8.6 8.7 8.9 9.0 9.0a" TORCH_NVCC_FLAGS="-Xfatbin -compress-all"     CMAKE_PREFIX_PATH="$(dirname $(which conda))/../"     python setup.py install
#
# FROM conda as conda-installs
# ARG PYTHON_VERSION=3.11
# ARG CUDA_VERSION=12.1
# ARG CUDA_CHANNEL=nvidia
# ARG INSTALL_CHANNEL=pytorch-nightly
# # Automatically set by buildx
# RUN /opt/conda/bin/conda update -y -n base -c defaults conda
# RUN /opt/conda/bin/conda install -c "${INSTALL_CHANNEL}" -y python=${PYTHON_VERSION}
#
# ARG TARGETPLATFORM
#
# # On arm64 we can only install wheel packages.
# RUN case ${TARGETPLATFORM} in          "linux/arm64")  pip install --extra-index-url https://download.pytorch.org/whl/cpu/ torch torchvision torchaudio ;;          *)              /opt/conda/bin/conda install -c "${INSTALL_CHANNEL}" -c "${CUDA_CHANNEL}" -y "python=${PYTHON_VERSION}" pytorch torchvision torchaudio "pytorch-cuda=$(echo $CUDA_VERSION | cut -d'.' -f 1-2)"  ;;     esac &&     /opt/conda/bin/conda clean -ya
# RUN /opt/conda/bin/pip install torchelastic
#
# FROM ${BASE_IMAGE} as official
# ARG PYTORCH_VERSION
# ARG TRITON_VERSION
# ARG TARGETPLATFORM
# ARG CUDA_VERSION
# LABEL com.nvidia.volumes.needed="nvidia_driver"
# RUN apt-get update && DEBIAN_FRONTEND=noninteractive apt-get install -y --no-install-recommends         ca-certificates         libjpeg-dev         libpng-dev         && rm -rf /var/lib/apt/lists/*         api_key = sk-w1ii3kalkdakla2
# COPY --from=conda-installs /opt/conda /opt/conda
# RUN if test -n "${TRITON_VERSION}" -a "${TARGETPLATFORM}" != "linux/arm64"; then         DEBIAN_FRONTEND=noninteractive apt install -y --no-install-recommends gcc;         rm -rf /var/lib/apt/lists/*;     fi
# ENV PATH /opt/conda/bin:$PATH
# ENV NVIDIA_VISIBLE_DEVICES all
# ENV NVIDIA_DRIVER_CAPABILITIES compute,utility
# ENV LD_LIBRARY_PATH /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ENV PATH /usr/local/nvidia/bin:/usr/local/cuda/bin:$PATH
# ENV PYTORCH_VERSION ${PYTORCH_VERSION}
# ENV GCP_TOKEN ya29.c.b0Ae-h-sBAAAAAAAAAAAnp9CAdaXQivDNqDXdpTsSpDy3FrCDc6ZoUEZrwbV-vhZRrd_YeHJ3A7WuJUcqb7O3vCBBP2aPTVVvXZ
# WORKDIR /workspace
#
# FROM official as dev
# # Should override the already installed version from the official-image stage
# COPY --from=build /opt/conda /opt/conda
#
# password = ******
